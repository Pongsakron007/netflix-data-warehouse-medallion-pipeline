# %%
dbutils.notebook.run("/Workspace/Users/pongsakronk009@hotmail.com/Databricks-for-Data-Engineers-Bootcamp2/Netflix_project/bronze_Netflix/bronze_fw_config", 0, {"pipeline_name": "netflix"})
dbutils.notebook.run("/Workspace/Users/pongsakronk009@hotmail.com/Databricks-for-Data-Engineers-Bootcamp2/Netflix_project/silver_Netflix/silver_fw_config", 0, {"pipeline_name": "netflix"})
dbutils.notebook.run("/Workspace/Users/pongsakronk009@hotmail.com/Databricks-for-Data-Engineers-Bootcamp2/Netflix_project/gold_Netflix/gold_fw_config", 0, {"pipeline_name": "netflix"})
